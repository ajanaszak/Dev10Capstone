# %%
def error_cb(err):
    """ The error callback is used for generic client errors. These
        errors are generally to be considered informational as the client will
        automatically try to recover from all errors, and no extra action
        is typically required by the application.
        For this example however, we terminate the application if the client
        is unable to connect to any broker (_ALL_BROKERS_DOWN) and on
        authentication errors (_AUTHENTICATION). """

    print("Client error: {}".format(err))
    if err.code() == KafkaError._ALL_BROKERS_DOWN or \
       err.code() == KafkaError._AUTHENTICATION:
        # Any exception raised from this callback will be re-raised from the
        # triggering flush() or poll() call.
        raise KafkaException(err)
        
from confluent_kafka import Consumer
from time import sleep
import uuid
from confluent_kafka import Producer, Consumer, KafkaError, KafkaException
import json


#KAFKA variables, Move to the OS variables or configuration
# This will work in local Jupiter Notebook, but in a databrick, hiding config.py is tougher. 
confluentClusterName = "stage3talent"
confluentBootstrapServers = "pkc-ldvmy.centralus.azure.confluent.cloud:9092"
confluentTopicName = "who-mortality-final"
schemaRegistryUrl = "https://psrc-gq7pv.westus2.azure.confluent.cloud"
confluentApiKey = "YHMHG7E54LJA55XZ"
confluentSecret = "/XYn+w3gHGMqpe9l0TWvA9FznMYNln2STI+dytyPqtZ9QktH0TbGXUqepEsJ/nR0"
confluentRegistryApiKey = "YHMHG7E54LJA55XZ"
confluentRegistrySecret = "/XYn+w3gHGMqpe9l0TWvA9FznMYNln2STI+dytyPqtZ9QktH0TbGXUqepEsJ/nR0"


#Kakfa Class Setup.
c = Consumer({
    'bootstrap.servers': confluentBootstrapServers,
    'sasl.mechanism': 'PLAIN',
    'security.protocol': 'SASL_SSL',
    'sasl.username': confluentApiKey,
    'sasl.password': confluentSecret,
    'group.id': str(uuid.uuid1()),  # this will create a new consumer group on each invocation.
    'auto.offset.reset': 'earliest',
    'error_cb': error_cb,
})

c.subscribe([confluentTopicName])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
aString = {}

kafkaListDictionaries = []

# We loop infinitely until we have consumed all the data or we get an error
while(True):
    try:
        msg = c.poll(timeout=1.0)
        if msg is None:
            break
        elif msg.error():
            print("Consumer error: {}".format(msg.error()))
            break
        else:
            aString=json.loads('{}'.format(msg.value().decode('utf-8')))
            kafkaListDictionaries.append(aString)
    except Exception as e:
        print(e)

# We make sure we're actually getting data
for message in kafkaListDictionaries:
    print(message)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2000, &#39;MortalityRatePer1000&#39;: 316}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2001, &#39;MortalityRatePer1000&#39;: 307}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2002, &#39;MortalityRatePer1000&#39;: 292}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2003, &#39;MortalityRatePer1000&#39;: 286}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2004, &#39;MortalityRatePer1000&#39;: 282}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2005, &#39;MortalityRatePer1000&#39;: 277}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2006, &#39;MortalityRatePer1000&#39;: 276}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2007, &#39;MortalityRatePer1000&#39;: 273}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2008, &#39;MortalityRatePer1000&#39;: 265}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2009, &#39;MortalityRatePer1000&#39;: 260}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2010, &#39;MortalityRatePer1000&#39;: 255}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2011, &#39;MortalityRatePer1000&#39;: 248}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2012, &#39;MortalityRatePer1000&#39;: 242}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2013, &#39;MortalityRatePer1000&#39;: 235}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2014, &#39;MortalityRatePer1000&#39;: 234}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2015, &#39;MortalityRatePer1000&#39;: 233}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2016, &#39;MortalityRatePer1000&#39;: 245}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2000, &#39;MortalityRatePer1000&#39;: 384}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2001, &#39;MortalityRatePer1000&#39;: 372}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2002, &#39;MortalityRatePer1000&#39;: 355}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2003, &#39;MortalityRatePer1000&#39;: 343}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2004, &#39;MortalityRatePer1000&#39;: 334}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2005, &#39;MortalityRatePer1000&#39;: 323}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2006, &#39;MortalityRatePer1000&#39;: 314}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2007, &#39;MortalityRatePer1000&#39;: 303}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2008, &#39;MortalityRatePer1000&#39;: 292}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2009, &#39;MortalityRatePer1000&#39;: 281}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2010, &#39;MortalityRatePer1000&#39;: 270}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2011, &#39;MortalityRatePer1000&#39;: 260}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2012, &#39;MortalityRatePer1000&#39;: 253}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2013, &#39;MortalityRatePer1000&#39;: 249}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2014, &#39;MortalityRatePer1000&#39;: 244}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2015, &#39;MortalityRatePer1000&#39;: 240}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2016, &#39;MortalityRatePer1000&#39;: 238}
# {&#39;Country&#39;: &#39;ALB&#39;, &#39;Year&#39;: 2000, &#39;MortalityRatePer1000&#39;: 106}
# {&#39;Country&#39;: &#39;ALB&#39;, &#39;Year&#39;: 2001, &#39;MortalityRatePer1000&#39;: 100}
# {&#39;Country&#39;: &#39;ALB&#39;, &#39;Year&#39;: 2002, &#39;MortalityRatePer1000&#39;: 102}
# {&#39;Country&#39;: &#39;ALB&#39;, &#39;Year&#39;: 2003, &#39;MortalityRatePer1000&#39;: 107}
# {&#39;Country&#39;: &#39;ALB&#39;, &#39;Year&#39;: 2004, &#39;MortalityRatePer1000&#39;: 101}
# {&#39;Country&#39;: &#39;ALB&#39;, &#39;Year&#39;: 2005, &#39;MortalityRatePer1000&#39;: 106}
# {&#39;Country&#39;: &#39;ALB&#39;, &#39;Year&#39;: 2006, &#39;MortalityRatePer1000&#39;: 101}
# {&#39;Country&#39;: &#39;ALB&#39;, &#39;Year&#39;: 2007, &#39;MortalityRatePer1000&#39;: 101}
# {&#39;Country&#39;: &#39;ALB&#39;, &#39;Year&#39;: 2008, &#39;MortalityRatePer1000&#39;: 102}
# {&#39;Country&#39;: &#39;ALB&#39;, &#39;Year&#39;: 2009, &#39;MortalityRatePer1000&#39;: 103}
# {&#39;Country&#39;: &#39;ALB&#39;, &#39;Year&#39;: 2010, &#39;MortalityRatePer1000&#39;: 103}
# {&#39;Country&#39;: &#39;ALB&#39;, &#39;Year&#39;: 2011, &#39;MortalityRatePer1000&#39;: 103}
# {&#39;Country&#39;: &#39;ALB&#39;, &#39;Year&#39;: 2012, &#39;MortalityRatePer1000&#39;: 103}
# {&#39;Country&#39;: &#39;ALB&#39;, &#39;Year&#39;: 2013, &#39;MortalityRatePer1000&#39;: 100}
# {&#39;Country&#39;: &#39;ALB&#39;, &#39;Year&#39;: 2014, &#39;MortalityRatePer1000&#39;: 98}
# {&#39;Country&#39;: &#39;ALB&#39;, &#39;Year&#39;: 2015, &#39;MortalityRatePer1000&#39;: 92}
# {&#39;Country&#39;: &#39;ALB&#39;, &#39;Year&#39;: 2016, &#39;MortalityRatePer1000&#39;: 96}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2000, &#39;MortalityRatePer1000&#39;: 107}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2001, &#39;MortalityRatePer1000&#39;: 104}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2002, &#39;MortalityRatePer1000&#39;: 101}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2003, &#39;MortalityRatePer1000&#39;: 98}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2004, &#39;MortalityRatePer1000&#39;: 94}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2005, &#39;MortalityRatePer1000&#39;: 91}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2006, &#39;MortalityRatePer1000&#39;: 88}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2007, &#39;MortalityRatePer1000&#39;: 86}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2008, &#39;MortalityRatePer1000&#39;: 85}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2009, &#39;MortalityRatePer1000&#39;: 83}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2010, &#39;MortalityRatePer1000&#39;: 81}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2011, &#39;MortalityRatePer1000&#39;: 80}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2012, &#39;MortalityRatePer1000&#39;: 79}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2013, &#39;MortalityRatePer1000&#39;: 78}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2014, &#39;MortalityRatePer1000&#39;: 76}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2015, &#39;MortalityRatePer1000&#39;: 75}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2016, &#39;MortalityRatePer1000&#39;: 74}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2000, &#39;MortalityRatePer1000&#39;: 139}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2001, &#39;MortalityRatePer1000&#39;: 138}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2002, &#39;MortalityRatePer1000&#39;: 137}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2003, &#39;MortalityRatePer1000&#39;: 134}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2004, &#39;MortalityRatePer1000&#39;: 128}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2005, &#39;MortalityRatePer1000&#39;: 125}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2006, &#39;MortalityRatePer1000&#39;: 124}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2007, &#39;MortalityRatePer1000&#39;: 126}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2008, &#39;MortalityRatePer1000&#39;: 123}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2009, &#39;MortalityRatePer1000&#39;: 123}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2010, &#39;MortalityRatePer1000&#39;: 119}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2011, &#39;MortalityRatePer1000&#39;: 118}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2012, &#39;MortalityRatePer1000&#39;: 118}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2013, &#39;MortalityRate

# %%
# We transform the list of dictionaries from the consumer into a dataframe
df = spark.createDataFrame(kafkaListDictionaries)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
###### Mount Point 1 through Oauth security.https://adb-593121260067740.0.azuredatabricks.net/?o=593121260067740#
storageAccount = "gen10dbcdatalake"
storageContainer = "group4-capstone"
clientSecret = "~bJ7Q~KslVT~sAmHkOLXL0oeTp1ZkAcndtHPr"
clientid = "2ca50102-5717-4373-b796-39d06568588d"
mount_point = "/mnt/portal/mortality"
#20200906-20201006/Detroit911-20200906-20201006.csv


configs = {"fs.azure.account.auth.type": "OAuth",
       "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
       "fs.azure.account.oauth2.client.id": clientid,
       "fs.azure.account.oauth2.client.secret": clientSecret,
       "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/d46b54b2-a652-420b-aa5a-2ef7f8fc706e/oauth2/token",
       "fs.azure.createRemoteFileSystemDuringInitialization": "true"}

try: 
    dbutils.fs.unmount(mount_point)
except:
    pass

dbutils.fs.mount(
source = "abfss://"+storageContainer+"@"+storageAccount+".dfs.core.windows.net/",
mount_point = mount_point,
extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/portal/mortality has been unmounted.
# Out[18]: True</div>

# %%
# We write to CSV, in a folder called "mortality"
df.write.mode('append').option("header", "true").csv('mnt/portal/mortality/mortality')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
