# %%
def error_cb(err):
    """ The error callback is used for generic client errors. These
        errors are generally to be considered informational as the client will
        automatically try to recover from all errors, and no extra action
        is typically required by the application.
        For this example however, we terminate the application if the client
        is unable to connect to any broker (_ALL_BROKERS_DOWN) and on
        authentication errors (_AUTHENTICATION). """

    print("Client error: {}".format(err))
    if err.code() == KafkaError._ALL_BROKERS_DOWN or \
       err.code() == KafkaError._AUTHENTICATION:
        # Any exception raised from this callback will be re-raised from the
        # triggering flush() or poll() call.
        raise KafkaException(err)
        
from confluent_kafka import Consumer
from time import sleep
import uuid
from confluent_kafka import Producer, Consumer, KafkaError, KafkaException
import json


#KAFKA variables, Move to the OS variables or configuration
# This will work in local Jupiter Notebook, but in a databrick, hiding config.py is tougher. 
confluentClusterName = "stage3talent"
confluentBootstrapServers = "pkc-ldvmy.centralus.azure.confluent.cloud:9092"
confluentTopicName = "who-malaria-final"
schemaRegistryUrl = "https://psrc-gq7pv.westus2.azure.confluent.cloud"
confluentApiKey = "YHMHG7E54LJA55XZ"
confluentSecret = "/XYn+w3gHGMqpe9l0TWvA9FznMYNln2STI+dytyPqtZ9QktH0TbGXUqepEsJ/nR0"
confluentRegistryApiKey = "YHMHG7E54LJA55XZ"
confluentRegistrySecret = "/XYn+w3gHGMqpe9l0TWvA9FznMYNln2STI+dytyPqtZ9QktH0TbGXUqepEsJ/nR0"


#Kakfa Class Setup.
c = Consumer({
    'bootstrap.servers': confluentBootstrapServers,
    'sasl.mechanism': 'PLAIN',
    'security.protocol': 'SASL_SSL',
    'sasl.username': confluentApiKey,
    'sasl.password': confluentSecret,
    'group.id': str(uuid.uuid1()),  # this will create a new consumer group on each invocation.
    'auto.offset.reset': 'earliest',
    'error_cb': error_cb,
})

c.subscribe([confluentTopicName])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
aString = {}

kafkaListDictionaries = []

# We loop through, querying until we have consumed everything in the topic
while(True):
    try:
        msg = c.poll(timeout=1.0)
        if msg is None:
            break
        elif msg.error():
            print("Consumer error: {}".format(msg.error()))
            break
        else:
            aString=json.loads('{}'.format(msg.value().decode('utf-8')))
            kafkaListDictionaries.append(aString)
    except Exception as e:
        print(e)

# We want to check to see that we're actually getting data
for message in kafkaListDictionaries:
    print(message)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2019, &#39;MalariaRatePer1000&#39;: 14.0}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2018, &#39;MalariaRatePer1000&#39;: 22.0}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2017, &#39;MalariaRatePer1000&#39;: 20.0}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2016, &#39;MalariaRatePer1000&#39;: 23.0}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2015, &#39;MalariaRatePer1000&#39;: 13.0}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2014, &#39;MalariaRatePer1000&#39;: 9.0}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2013, &#39;MalariaRatePer1000&#39;: 7.0}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2012, &#39;MalariaRatePer1000&#39;: 9.0}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2011, &#39;MalariaRatePer1000&#39;: 15.0}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2010, &#39;MalariaRatePer1000&#39;: 12.0}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2009, &#39;MalariaRatePer1000&#39;: 12.0}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2008, &#39;MalariaRatePer1000&#39;: 17.0}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2007, &#39;MalariaRatePer1000&#39;: 21.0}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2006, &#39;MalariaRatePer1000&#39;: 20.0}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2005, &#39;MalariaRatePer1000&#39;: 27.0}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2004, &#39;MalariaRatePer1000&#39;: 37.0}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2003, &#39;MalariaRatePer1000&#39;: 68.0}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2002, &#39;MalariaRatePer1000&#39;: 79.0}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2001, &#39;MalariaRatePer1000&#39;: 79.0}
# {&#39;Country&#39;: &#39;AFG&#39;, &#39;Year&#39;: 2000, &#39;MalariaRatePer1000&#39;: 82.0}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2019, &#39;MalariaRatePer1000&#39;: 235.0}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2018, &#39;MalariaRatePer1000&#39;: 227.0}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2017, &#39;MalariaRatePer1000&#39;: 216.0}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2016, &#39;MalariaRatePer1000&#39;: 205.0}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2015, &#39;MalariaRatePer1000&#39;: 189.0}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2014, &#39;MalariaRatePer1000&#39;: 179.0}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2013, &#39;MalariaRatePer1000&#39;: 172.0}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2012, &#39;MalariaRatePer1000&#39;: 165.0}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2011, &#39;MalariaRatePer1000&#39;: 166.0}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2010, &#39;MalariaRatePer1000&#39;: 175.0}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2009, &#39;MalariaRatePer1000&#39;: 193.0}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2008, &#39;MalariaRatePer1000&#39;: 227.0}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2007, &#39;MalariaRatePer1000&#39;: 272.0}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2006, &#39;MalariaRatePer1000&#39;: 302.0}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2005, &#39;MalariaRatePer1000&#39;: 317.0}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2004, &#39;MalariaRatePer1000&#39;: 317.0}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2003, &#39;MalariaRatePer1000&#39;: 312.0}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2002, &#39;MalariaRatePer1000&#39;: 309.0}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2001, &#39;MalariaRatePer1000&#39;: 325.0}
# {&#39;Country&#39;: &#39;AGO&#39;, &#39;Year&#39;: 2000, &#39;MalariaRatePer1000&#39;: 321.0}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2019, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2018, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2017, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2016, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2015, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2014, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2013, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2012, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2011, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2010, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2009, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2008, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2007, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2006, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2005, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2004, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2003, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2002, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2001, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARE&#39;, &#39;Year&#39;: 2000, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2019, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2018, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2017, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2016, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2015, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2014, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2013, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2012, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2011, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2010, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2009, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2008, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2007, &#39;MalariaRatePer1000&#39;: 1.0}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2006, &#39;MalariaRatePer1000&#39;: 1.0}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2005, &#39;MalariaRatePer1000&#39;: 1.0}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2004, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2003, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2002, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2001, &#39;MalariaRatePer1000&#39;: 1.0}
# {&#39;Country&#39;: &#39;ARG&#39;, &#39;Year&#39;: 2000, &#39;MalariaRatePer1000&#39;: 2.0}
# {&#39;Country&#39;: &#39;ARM&#39;, &#39;Year&#39;: 2019, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARM&#39;, &#39;Year&#39;: 2018, &#39;MalariaRatePer1000&#39;: 0.0}
# {&#39;Country&#39;: &#39;ARM&#39;, &#39;Year&#39;: 2017, &#39;MalariaRa

# %%
df = spark.createDataFrame(kafkaListDictionaries)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
###### Mount Point 1 through Oauth security.https://adb-593121260067740.0.azuredatabricks.net/?o=593121260067740#
storageAccount = "gen10dbcdatalake"
storageContainer = "group4-capstone"
clientSecret = "~bJ7Q~KslVT~sAmHkOLXL0oeTp1ZkAcndtHPr"
clientid = "2ca50102-5717-4373-b796-39d06568588d"
mount_point = "/mnt/portal/malaria"
#20200906-20201006/Detroit911-20200906-20201006.csv


configs = {"fs.azure.account.auth.type": "OAuth",
       "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
       "fs.azure.account.oauth2.client.id": clientid,
       "fs.azure.account.oauth2.client.secret": clientSecret,
       "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/d46b54b2-a652-420b-aa5a-2ef7f8fc706e/oauth2/token",
       "fs.azure.createRemoteFileSystemDuringInitialization": "true"}

try: 
    dbutils.fs.unmount(mount_point)
except:
    pass

dbutils.fs.mount(
source = "abfss://"+storageContainer+"@"+storageAccount+".dfs.core.windows.net/",
mount_point = mount_point,
extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/portal/malaria has been unmounted.
# Out[7]: True</div>

# %%
# We write to the datalake in a folder called "malaria"
df.write.mode('append').option("header", "true").csv('mnt/portal/malaria/malaria')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
